# %% [markdown]
# Plot MICRESS® data with gnuplot
# ===============================
#
# Average grain radius over time
# ------------------------------
#
# ### Plot multiple files

# %%
unset key
set xlabel "Time [s]"
set ylabel "Average grain size [{/Symbol m}m]"
plot "Test/T025_GrainGrowth.TabK" u 1:2 w l, \
     "Test/T026_GrainGrowth_Misorientation.TabK" u 1:2 w l
